# %%
from langchain_community.document_loaders import DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.schema import Document

# %%
from chromadb import PersistentClient
from langchain_chroma import Chroma
from langchain_ollama import OllamaEmbeddings

CHROMA_PATH = "./chroma"

embeddings = OllamaEmbeddings(
    base_url="http://localhost:11434",
    model="qwen3"
)

persistent_client = PersistentClient(
    path=CHROMA_PATH,
)

collection_name = "data"
collection = persistent_client.get_or_create_collection(name=collection_name)

vector_store = Chroma(
    client=persistent_client,
    collection_name=collection_name,
    embedding_function=embeddings,
)

def doc_to_id(doc):
    return f"{doc.metadata['source_type']}_{doc.metadata['source_dir']}_{doc.metadata['chunk_number']}"

# Add documents to the vector store
def add_documents_to_vector_store(documents):
    # filter out documents that are already in the vector store
    existing_ids = set(vector_store.get()['ids'])

    # if the ID is already in the vector store, update the metadata
    for doc in documents:
        doc_id = doc_to_id(doc)
        if doc_id in existing_ids:
            collection.update(
                ids=[doc_id],
                metadatas=[doc.metadata],
            )
            print(f"Updated metadata for document ID: {doc_id}")

    documents = [
        doc for doc in documents
        if doc_to_id(doc) not in existing_ids
    ]

    print(f"Adding {len(documents)} new documents to the vector store...")

    # if more than 1000 documents, make multiple calls
    CHUNK_SIZE = 10
    for i in range(0, len(documents), CHUNK_SIZE):
        batch = documents[i:i + CHUNK_SIZE]
        print(batch)
        vector_store.add_documents(
            documents=batch,
            ids=[doc_to_id(doc) for doc in batch],
        )
        print(f"Added {len(batch)} documents to the vector store.")
# Out:
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given

# %%
DATA_PATH = './flat_content'

def main():
    generate_data_store()


def generate_data_store():
    documents = load_documents()
    chunks = split_text(documents)
    save_to_chroma(chunks)


def load_documents():
    loader = DirectoryLoader(DATA_PATH, glob="*.md")
    documents = loader.load()

    # Add metadata to each document
    for doc in documents:
        doc.metadata['source_type'] = 'markdown'
        doc.metadata['source_dir'] = DATA_PATH

    return documents


def split_text(documents: list[Document]):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=400,
        chunk_overlap=100,
        length_function=len,
        add_start_index=True,
    )
    chunks = text_splitter.split_documents(documents)

    # Add metadata to each chunk
    for i, chunk in enumerate(chunks):
        chunk.metadata['chunk_number'] = i + 1

    print(f"Split {len(documents)} documents into {len(chunks)} chunks.")

    document = chunks[10]
    print(document.page_content)
    print(document.metadata)

    return chunks


def save_to_chroma(chunks: list[Document]):
    add_documents_to_vector_store(chunks)
    print("Data store generated successfully.")

# %%
if __name__ == "__main__":
    main()
# Out:
# Split 1479 documents into 13516 chunks.
# |3.4.1 | - | 3.1.2 | |tensorflow |2.13.0 | - | 2.7.0, 2.10.0 | |texlive |2023 | - | 2020 | {{< /table >}}
# {'source': 'flat_content/learning_content_post_2023-december-maintenance.md', 'source_type': 'markdown', 'source_dir': './flat_content', 'start_index': 2602, 'chunk_number': 11}
# Failed to send telemetry event CollectionUpdateEvent: capture() takes 1 positional argument but 3 were given
# Updated metadata for document ID: markdown_./flat_content_1
# Updated metadata for document ID: markdown_./flat_content_2
# Updated metadata for document ID: markdown_./flat_content_3
# Updated metadata for document ID: markdown_./flat_content_4
# Updated metadata for document ID: markdown_./flat_content_5
# Updated metadata for document ID: markdown_./flat_content_6
# Updated metadata for document ID: markdown_./flat_content_7
# Updated metadata for document ID: markdown_./flat_content_8
# Updated metadata for document ID: markdown_./flat_content_9
# ...
