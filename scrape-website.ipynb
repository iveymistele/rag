# %%
from langchain_ollama import OllamaEmbeddings
from langchain_postgres import PGEngine, PGVectorStore

CONNECTION_STRING = "postgresql+psycopg://user:password@localhost:5432/vector_db"
COLLECTION_NAME = "documents"
VECTOR_SIZE = 768  # Adjust based on the model's output vector size

embeddings = OllamaEmbeddings(
    base_url="http://localhost:11434",
    model="nomic-embed-text"
)

engine = PGEngine.from_connection_string(url=CONNECTION_STRING)

# engine.init_vectorstore_table(
#     table_name=COLLECTION_NAME,
#     vector_size=VECTOR_SIZE,
# )

vector_store = PGVectorStore.create_sync(
    engine=engine,
    embedding_service=embeddings,
    table_name=COLLECTION_NAME,
)

# Add documents to the vector store
def add_documents_to_vector_store(documents):
    vector_store.add_documents(
        documents=documents,
        ids=[doc.metadata['source_type'] + "_" + doc.metadata['source'] + "_" + str(doc.metadata['chunk_number']) for doc in documents],
    )

    print(f"Added {len(documents)} documents to the vector store.")
# Out:
# ---------------------------------------------------------------------------
# DuplicateTable                            Traceback (most recent call last)
# File /Projects/rc/rag-hpc-rc/venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1963, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1962     if not evt_handled:
# -> 1963         self.dialect.do_execute(
#    1964             cursor, str_statement, effective_parameters, context
#    1965         )
#    1967 if self._has_events or self.engine._has_events:
#
# File /Projects/rc/rag-hpc-rc/venv/lib/python3.10/site-packages/sqlalchemy/engine/default.py:943, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     942 def do_execute(self, cursor, statement, parameters, context=None):
# --> 943     cursor.execute(statement, parameters)
#
# File /Projects/rc/rag-hpc-rc/venv/lib/python3.10/site-packages/sqlalchemy/dialects/postgresql/psycopg.py:594, in AsyncAdapt_psycopg_cursor.execute(self, query, params, **kw)
#     593 def execute(self, query, params=None, **kw):
# --> 594     result = self.await_(self._cursor.execute(query, params, **kw))
#     595     # sqlalchemy result is not async, so need to pull all rows here
#
# File /Projects/rc/rag-hpc-rc/venv/lib/python3.10/site-packages/sqlalchemy/util/_concurrency_py3k.py:132, in await_only(awaitable)
#     128 # returns the control to the driver greenlet passing it
#     129 # a coroutine to run. Once the awaitable is done, the driver greenlet
#     130 # switches back to this greenlet with the result of awaitable that is
#     131 # then returned to the caller (or raised as error)
# --> 132 return current.parent.switch(awaitable)
#
# File /Projects/rc/rag-hpc-rc/venv/lib/python3.10/site-packages/sqlalchemy/util/_concurrency_py3k.py:196, in greenlet_spawn(fn, _require_await, *args, **kwargs)
#     193 try:
#     194     # wait for a coroutine from await_only and then return its
#     195     # result back to it.
# --> 196     value = await result
#     197 except BaseException:
#     198     # this allows an exception to be raised within
#     199     # the moderated greenlet so that it can continue
#     200     # its expected flow.
#
# File /Projects/rc/rag-hpc-rc/venv/lib/python3.10/site-packages/psycopg/cursor_async.py:97, in AsyncCursor.execute(self, query, params, prepare, binary)
#      96 except e._NO_TRACEBACK as ex:
# ---> 97     raise ex.with_traceback(None)
#      98 return self
#
# DuplicateTable: relation "documents" already exists
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[18], line 15
#       8 embeddings = OllamaEmbeddings(
#       9     base_url="http://localhost:11434",
#      10     model="nomic-embed-text"
#      11 )
#      13 engine = PGEngine.from_connection_string(url=CONNECTION_STRING)
# ---> 15 engine.init_vectorstore_table(
#      16     table_name=COLLECTION_NAME,
#      17     vector_size=VECTOR_SIZE,
#      18 )
#      20 vector_store = PGVectorStore.create_sync(
#      21     engine=engine,
#      22     embedding_service=embeddings,
#      23     table_name=COLLECTION_NAME,
#      24 )
#      26 # Add documents to the vector store
#
# File /Projects/rc/rag-hpc-rc/venv/lib/python3.10/site-packages/langchain_postgres/v2/engine.py:364, in PGEngine.init_vectorstore_table(self, table_name, vector_size, schema_name, content_column, embedding_column, metadata_columns, metadata_json_column, id_column, overwrite_existing, store_metadata, hybrid_search_config)
#     323 def init_vectorstore_table(
#     324     self,
#     325     table_name: str,
#    (...)
#     336     hybrid_search_config: Optional[HybridSearchConfig] = None,
#     337 ) -> None:
#     338     """
#     339     Create a table for saving of vectors to be used with PGVectorStore.
#     340
#    (...)
#     362             Default: None.
#     363     """
# --> 364     self._run_as_sync(
#     365         self._ainit_vectorstore_table(
#     366             table_name,
#     367             vector_size,
#     368             schema_name=schema_name,
#     369             content_column=content_column,
#     370             embedding_column=embedding_column,
#     371             metadata_columns=metadata_columns,
#     372             metadata_json_column=metadata_json_column,
#     373             id_column=id_column,
#     374             overwrite_existing=overwrite_existing,
#     375             store_metadata=store_metadata,
#     376             hybrid_search_config=hybrid_search_config,
#     377         )
#     378     )
#
# File /Projects/rc/rag-hpc-rc/venv/lib/python3.10/site-packages/langchain_postgres/v2/engine.py:131, in PGEngine._run_as_sync(self, coro)
#     127 if not self._loop:
#     128     raise Exception(
#     129         "Engine was initialized without a background loop and cannot call sync methods."
#     130     )
# --> 131 return asyncio.run_coroutine_threadsafe(coro, self._loop).result()
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/concurrent/futures/_base.py:445, in Future.result(self, timeout)
#     443     raise CancelledError()
#     444 elif self._state == FINISHED:
# --> 445     return self.__get_result()
#     446 else:
#     447     raise TimeoutError()
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/concurrent/futures/_base.py:390, in Future.__get_result(self)
#     388 if self._exception:
#     389     try:
# --> 390         raise self._exception
#     391     finally:
#     392         # Break a reference cycle with the exception in self._exception
#     393         self = None
#
# File /Projects/rc/rag-hpc-rc/venv/lib/python3.10/site-packages/langchain_postgres/v2/engine.py:263, in PGEngine._ainit_vectorstore_table(self, table_name, vector_size, schema_name, content_column, embedding_column, metadata_columns, metadata_json_column, id_column, overwrite_existing, store_metadata, hybrid_search_config)
#     260 query += "\n);"
#     262 async with self._pool.connect() as conn:
# --> 263     await conn.execute(text(query))
#     264     await conn.commit()
#
# File /Projects/rc/rag-hpc-rc/venv/lib/python3.10/site-packages/sqlalchemy/ext/asyncio/engine.py:658, in AsyncConnection.execute(self, statement, parameters, execution_options)
#     620 async def execute(
#     621     self,
#     622     statement: Executable,
#    (...)
#     625     execution_options: Optional[CoreExecuteOptionsParameter] = None,
#     626 ) -> CursorResult[Any]:
#     627     r"""Executes a SQL statement construct and return a buffered
#     628     :class:`_engine.Result`.
#     629
#    (...)
#     656
#     657     """
# --> 658     result = await greenlet_spawn(
#     659         self._proxied.execute,
#     660         statement,
#     661         parameters,
#     662         execution_options=execution_options,
#     663         _require_await=True,
#     664     )
#     665     return await _ensure_sync_result(result, self.execute)
#
# File /Projects/rc/rag-hpc-rc/venv/lib/python3.10/site-packages/sqlalchemy/util/_concurrency_py3k.py:201, in greenlet_spawn(fn, _require_await, *args, **kwargs)
#     196     value = await result
#     197 except BaseException:
#     198     # this allows an exception to be raised within
#     199     # the moderated greenlet so that it can continue
#     200     # its expected flow.
# --> 201     result = context.throw(*sys.exc_info())
#     202 else:
#     203     result = context.switch(value)
#
# File /Projects/rc/rag-hpc-rc/venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1415, in Connection.execute(self, statement, parameters, execution_options)
#    1413     raise exc.ObjectNotExecutableError(statement) from err
#    1414 else:
# -> 1415     return meth(
#    1416         self,
#    1417         distilled_parameters,
#    1418         execution_options or NO_OPTIONS,
#    1419     )
#
# File /Projects/rc/rag-hpc-rc/venv/lib/python3.10/site-packages/sqlalchemy/sql/elements.py:523, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     521     if TYPE_CHECKING:
#     522         assert isinstance(self, Executable)
# --> 523     return connection._execute_clauseelement(
#     524         self, distilled_params, execution_options
#     525     )
#     526 else:
#     527     raise exc.ObjectNotExecutableError(self)
#
# File /Projects/rc/rag-hpc-rc/venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1637, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1625 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1626     "compiled_cache", self.engine._compiled_cache
#    1627 )
#    1629 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1630     dialect=dialect,
#    1631     compiled_cache=compiled_cache,
#    (...)
#    1635     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1636 )
# -> 1637 ret = self._execute_context(
#    1638     dialect,
#    1639     dialect.execution_ctx_cls._init_compiled,
#    1640     compiled_sql,
#    1641     distilled_parameters,
#    1642     execution_options,
#    1643     compiled_sql,
#    1644     distilled_parameters,
#    1645     elem,
#    1646     extracted_params,
#    1647     cache_hit=cache_hit,
#    1648 )
#    1649 if has_events:
#    1650     self.dispatch.after_execute(
#    1651         self,
#    1652         elem,
#    (...)
#    1656         ret,
#    1657     )
#
# File /Projects/rc/rag-hpc-rc/venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1842, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1840     return self._exec_insertmany_context(dialect, context)
#    1841 else:
# -> 1842     return self._exec_single_context(
#    1843         dialect, context, statement, parameters
#    1844     )
#
# File /Projects/rc/rag-hpc-rc/venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1982, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1979     result = context._setup_result_proxy()
#    1981 except BaseException as e:
# -> 1982     self._handle_dbapi_exception(
#    1983         e, str_statement, effective_parameters, cursor, context
#    1984     )
#    1986 return result
#
# File /Projects/rc/rag-hpc-rc/venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2351, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2349 elif should_wrap:
#    2350     assert sqlalchemy_exception is not None
# -> 2351     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2352 else:
#    2353     assert exc_info[1] is not None
#
# File /Projects/rc/rag-hpc-rc/venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1963, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1961                 break
#    1962     if not evt_handled:
# -> 1963         self.dialect.do_execute(
#    1964             cursor, str_statement, effective_parameters, context
#    1965         )
#    1967 if self._has_events or self.engine._has_events:
#    1968     self.dispatch.after_cursor_execute(
#    1969         self,
#    1970         cursor,
#    (...)
#    1974         context.executemany,
#    1975     )
#
# File /Projects/rc/rag-hpc-rc/venv/lib/python3.10/site-packages/sqlalchemy/engine/default.py:943, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     942 def do_execute(self, cursor, statement, parameters, context=None):
# --> 943     cursor.execute(statement, parameters)
#
# File /Projects/rc/rag-hpc-rc/venv/lib/python3.10/site-packages/sqlalchemy/dialects/postgresql/psycopg.py:594, in AsyncAdapt_psycopg_cursor.execute(self, query, params, **kw)
#     593 def execute(self, query, params=None, **kw):
# --> 594     result = self.await_(self._cursor.execute(query, params, **kw))
#     595     # sqlalchemy result is not async, so need to pull all rows here
#     596     res = self._cursor.pgresult
#
# File /Projects/rc/rag-hpc-rc/venv/lib/python3.10/site-packages/sqlalchemy/util/_concurrency_py3k.py:132, in await_only(awaitable)
#     123     raise exc.MissingGreenlet(
#     124         "greenlet_spawn has not been called; can't call await_only() "
#     125         "here. Was IO attempted in an unexpected place?"
#     126     )
#     128 # returns the control to the driver greenlet passing it
#     129 # a coroutine to run. Once the awaitable is done, the driver greenlet
#     130 # switches back to this greenlet with the result of awaitable that is
#     131 # then returned to the caller (or raised as error)
# --> 132 return current.parent.switch(awaitable)
#
# File /Projects/rc/rag-hpc-rc/venv/lib/python3.10/site-packages/sqlalchemy/util/_concurrency_py3k.py:196, in greenlet_spawn(fn, _require_await, *args, **kwargs)
#     192 switch_occurred = True
#     193 try:
#     194     # wait for a coroutine from await_only and then return its
#     195     # result back to it.
# --> 196     value = await result
#     197 except BaseException:
#     198     # this allows an exception to be raised within
#     199     # the moderated greenlet so that it can continue
#     200     # its expected flow.
#     201     result = context.throw(*sys.exc_info())
#
# File /Projects/rc/rag-hpc-rc/venv/lib/python3.10/site-packages/psycopg/cursor_async.py:97, in AsyncCursor.execute(self, query, params, prepare, binary)
#      93         await self._conn.wait(
#      94             self._execute_gen(query, params, prepare=prepare, binary=binary)
#      95         )
#      96 except e._NO_TRACEBACK as ex:
# ---> 97     raise ex.with_traceback(None)
#      98 return self
#
# ProgrammingError: (psycopg.errors.DuplicateTable) relation "documents" already exists
# [SQL: CREATE TABLE "public"."documents"(
#             "langchain_id" UUID PRIMARY KEY,
#             "content" TEXT NOT NULL,
#             "embedding" vector(768) NOT NULL
#             ,
# "langchain_metadata" JSON
# );]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
import requests
from bs4 import BeautifulSoup
import re
from urllib.parse import urlparse, urljoin
import time

# List of file extensions to skip
SKIP_EXTENSIONS = (".png", ".jpg", ".jpeg", ".gif", ".bmp", ".svg", ".pdf", ".zip", ".tar", ".gz", ".mp4", ".webp")

def is_valid(url, netloc):
    parsed = urlparse(url)
    path = parsed.path.lower()
    return (
        parsed.scheme in {"http", "https"}
        and netloc in parsed.netloc
        and not path.endswith(SKIP_EXTENSIONS)
    )

def crawl(url, visited=set(), documents={}, netloc=None):
    if url in visited:
        return documents
    visited.add(url)

    netloc = netloc or urlparse(url).netloc

    try:
        response = requests.get(url, timeout=5)

        if response.url != url:
            print(f"Redirected from {url} to {response.url}")
            url = response.url
            if url in visited:
                return documents
            visited.add(url)

        content_type = response.headers.get("Content-Type", "")

        # Skip non-HTML content (e.g. image files served without .png in URL)
        if "text/html" not in content_type:
            print(f"Skipping non-HTML URL: {url}")
            return documents

        if response.status_code != 200:
            return documents

        soup = BeautifulSoup(response.text, "html.parser")

        if len(articles := soup.find_all("article")) != 1:
            print(f"Skipping {url} as it does not contain exactly one article")
        else:
            # Clear the soup to only contain the article content
            article_soup = BeautifulSoup(str(articles[0]), "html.parser")

            # Remove images before text extraction
            for tag in article_soup.find_all("img"):
                tag.decompose()

            # Remove "« Return to [previous page]" link
            return_link = article_soup.find("a", string=re.compile(r"^« Return to"))
            if return_link:
                return_link.decompose()

            metadata_tag = article_soup.find("p", class_="blog-post-meta")

            # Extract tags from the article metadata
            if metadata_tag:
                tags = [a_tag.get_text(strip=True) for a_tag in metadata_tag.find_all("a") if a_tag.get_text(strip=True)]
            else:
                tags = [a_tag.get_text(strip=True) for a_tag in article_soup.find_all("a", href=re.compile(r"^/tag/*")) if a_tag.get_text(strip=True)]
            
            date_tag = metadata_tag.find("time") if metadata_tag else None
            date_updated = date_tag['datetime'] if date_tag else None

            # Convert links to absolute URLs and convert to markdown format
            for a_tag in article_soup.find_all("a", href=True):
                href = a_tag['href']
                if not href.startswith("http"):
                    href = urljoin(url, href)
                a_tag['href'] = href
                a_tag.string = f"[{a_tag.get_text(strip=True)}]({href})"
            
            # Convert blog-post-title class to markdown
            title_tag = article_soup.find("h2", class_="blog-post-title")
            if title_tag:
                title_text = title_tag.get_text(strip=True)
                title_tag.string = f"# {title_text}\n\n"
            
            # Convert h1 tags to markdown
            for h1_tag in article_soup.find_all("h1"):
                h1_text = h1_tag.get_text(strip=True)
                h1_tag.string = f"\n\n## {h1_text}\n"
            
            # Remove tags from the article content
            if metadata_tag:
                metadata_tag.decompose()

            # Extract and clean text
            text = article_soup.get_text()
            text = re.sub(r"https?:\/\/\S+?\.png", "", text)  # remove .png URLs
            text = re.sub(r"\S+\.png", "", text)              # remove local refs
            text = re.sub(r"\n{3,}", "\n\n", text)
            text = re.sub(r"[ \t]+", " ", text)

            documents[url] = {
                "text": text.strip(),
                "metadata": {
                    "source_type": "website",
                    "source": url,
                    "chunk_number": 0,  # Assuming single chunk for simplicity
                    "tags": ["website", "blog-post"] + tags,
                    "date_updated": date_updated,
                }
            }
            print(f"Extracted text from {url}")
        
        # Crawl linked pages recursively
        for a_tag in soup.find_all("a", href=True):
            if a_tag['href'].startswith(("http://", "https://")) and not urlparse(a_tag['href']).netloc == netloc:
                continue

            next_url = urljoin(url, a_tag['href'])

            # if the url contains a #, remove it
            next_url = next_url.split('#')[0]

            if is_valid(next_url, netloc):
                crawl(next_url, visited, documents, netloc)

        time.sleep(0.1)

    except Exception as e:
        print(f"Failed to crawl {url}: {e}")
    
    return documents

# %%
documents = crawl("https://rc.virginia.edu/")
# Out:
# Skipping https://rc.virginia.edu/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/userinfo/hpc/access/
# Extracted text from https://rc.virginia.edu/userinfo/storage/
# Skipping https://rc.virginia.edu/categories/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/form/support-request/
# Extracted text from https://rc.virginia.edu/userinfo/systems/
# Extracted text from https://rc.virginia.edu/userinfo/user-guide/
# Skipping https://rc.virginia.edu/tags/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/about/mission/
# Skipping https://rc.virginia.edu/about/people/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/about/students/
# Extracted text from https://rc.virginia.edu/service/high-performance-computing/
# Extracted text from https://rc.virginia.edu/service/dac/
# Extracted text from https://rc.virginia.edu/service/dtc/
# Extracted text from https://rc.virginia.edu/service/imaging/
# Extracted text from https://rc.virginia.edu/service/bioinformatics/
# Extracted text from https://rc.virginia.edu/userinfo/microservices/
# Extracted text from https://rc.virginia.edu/service/cloud/
# Extracted text from https://rc.virginia.edu/userinfo/computing-environments/
# Extracted text from https://rc.virginia.edu/service/acknowledgement/
# Extracted text from https://rc.virginia.edu/service/status/
# Redirected from https://rc.virginia.edu/userinfo/faq to https://rc.virginia.edu/userinfo/faq/
# Extracted text from https://rc.virginia.edu/userinfo/faq/
# Redirected from https://rc.virginia.edu/userinfo/howtos to https://rc.virginia.edu/userinfo/howtos/
# Extracted text from https://rc.virginia.edu/userinfo/howtos/
# Redirected from https://rc.virginia.edu/userinfo/hpc to https://rc.virginia.edu/userinfo/hpc/
# Extracted text from https://rc.virginia.edu/userinfo/hpc/
# Redirected from https://rc.virginia.edu/userinfo/ivy to https://rc.virginia.edu/userinfo/ivy/
# Extracted text from https://rc.virginia.edu/userinfo/ivy/
# Redirected from https://rc.virginia.edu/userinfo/accord to https://rc.virginia.edu/userinfo/accord/
# Extracted text from https://rc.virginia.edu/userinfo/accord/
# Extracted text from https://rc.virginia.edu/userinfo/access-ci/
# Extracted text from https://rc.virginia.edu/userinfo/data-transfer/
# Extracted text from https://rc.virginia.edu/userinfo/pricing/
# Extracted text from https://rc.virginia.edu/education/workshops/
# Redirected from https://rc.virginia.edu/education/rivanna-instructional to https://rc.virginia.edu/education/rivanna-instructional/
# Extracted text from https://rc.virginia.edu/education/rivanna-instructional/
# Skipping https://rc.virginia.edu/project/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/support/
# Extracted text from https://rc.virginia.edu/form/storage/
# Extracted text from https://rc.virginia.edu/form/allocation-standard/
# Extracted text from https://rc.virginia.edu/form/allocation-purchase/
# Extracted text from https://rc.virginia.edu/form/allocation-instructional/
# Extracted text from https://rc.virginia.edu/form/containers/
# Redirected from https://rc.virginia.edu/form/dedicated-computing to https://rc.virginia.edu/form/dedicated-computing/
# Extracted text from https://rc.virginia.edu/form/dedicated-computing/
# Skipping https://rc.virginia.edu/search/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/2025/07/hpc-maintenance-aug-12-2025/
# Redirected from https://rc.virginia.edu/categories/feature to https://rc.virginia.edu/categories/feature/
# Skipping https://rc.virginia.edu/categories/feature/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/tags/afton to https://rc.virginia.edu/tags/afton/
# Skipping https://rc.virginia.edu/tags/afton/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/tags/rivanna to https://rc.virginia.edu/tags/rivanna/
# Skipping https://rc.virginia.edu/tags/rivanna/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/userinfo/hpc/slurm/
# Redirected from https://rc.virginia.edu/userinfo/hpc/slurm-script-generator to https://rc.virginia.edu/userinfo/hpc/slurm-script-generator/
# Extracted text from https://rc.virginia.edu/userinfo/hpc/slurm-script-generator/
# Redirected from https://rc.virginia.edu/userinfo/hpc/ood to https://rc.virginia.edu/userinfo/hpc/ood/
# Extracted text from https://rc.virginia.edu/userinfo/hpc/ood/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/jupyterlab to https://rc.virginia.edu/userinfo/hpc/software/jupyterlab/
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/jupyterlab/
# Redirected from https://rc.virginia.edu/userinfo/howtos/rivanna/custom-jupyter-kernels to https://rc.virginia.edu/userinfo/howtos/rivanna/custom-jupyter-kernels/
# Extracted text from https://rc.virginia.edu/userinfo/howtos/rivanna/custom-jupyter-kernels/
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/python/
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/miniforge/
# Redirected from https://rc.virginia.edu/categories/userinfo to https://rc.virginia.edu/categories/userinfo/
# Skipping https://rc.virginia.edu/categories/userinfo/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/tags/allocations to https://rc.virginia.edu/tags/allocations/
# Skipping https://rc.virginia.edu/tags/allocations/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/tags/hpc to https://rc.virginia.edu/tags/hpc/
# Skipping https://rc.virginia.edu/tags/hpc/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/tags/parallel-computing to https://rc.virginia.edu/tags/parallel-computing/
# Skipping https://rc.virginia.edu/tags/parallel-computing/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/tags/queues to https://rc.virginia.edu/tags/queues/
# Skipping https://rc.virginia.edu/tags/queues/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/tags/storage to https://rc.virginia.edu/tags/storage/
# Skipping https://rc.virginia.edu/tags/storage/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/tags/supercomputer to https://rc.virginia.edu/tags/supercomputer/
# Skipping https://rc.virginia.edu/tags/supercomputer/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/userinfo/hpc/job-alerts/
# Redirected from https://rc.virginia.edu/tags/gpu to https://rc.virginia.edu/tags/gpu/
# Skipping https://rc.virginia.edu/tags/gpu/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/tags/utilization to https://rc.virginia.edu/tags/utilization/
# Skipping https://rc.virginia.edu/tags/utilization/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/alphafold/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/alphafold/ https:/github.com/google-deepmind/alphafold3 to https://rc.virginia.edu/userinfo/hpc/software/alphafold/%20https:/github.com/google-deepmind/alphafold3
# Redirected from https://rc.virginia.edu/categories/hpc to https://rc.virginia.edu/categories/hpc/
# Skipping https://rc.virginia.edu/categories/hpc/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/julia/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/julia/ https:/julialang.org to https://rc.virginia.edu/userinfo/hpc/software/julia/%20https:/julialang.org
# Redirected from https://rc.virginia.edu/categories/software to https://rc.virginia.edu/categories/software/
# Skipping https://rc.virginia.edu/categories/software/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/categories/math to https://rc.virginia.edu/categories/math/
# Skipping https://rc.virginia.edu/categories/math/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/tags
https://rc.virginia.edu/userinfo/ivy/ivy-linux-sw/data-analysis/anaconda to https://rc.virginia.edu/userinfo/ivy/ivy-linux-sw/data-analysis/anaconda/
# Extracted text from https://rc.virginia.edu/userinfo/ivy/ivy-linux-sw/data-analysis/anaconda/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/miniforge to https://rc.virginia.edu/userinfo/hpc/software/miniforge/
# Redirected from https://rc.virginia.edu/userinfo/ivy/ivy-linux-sw/data-analysis/r to https://rc.virginia.edu/userinfo/ivy/ivy-linux-sw/data-analysis/r/
# Extracted text from https://rc.virginia.edu/userinfo/ivy/ivy-linux-sw/data-analysis/r/
# Redirected from https://rc.virginia.edu/tags/r to https://rc.virginia.edu/tags/r/
# Skipping https://rc.virginia.edu/tags/r/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/categories/education to https://rc.virginia.edu/categories/education/
# Skipping https://rc.virginia.edu/categories/education/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/2025/02/future-of-research-computings-training-initiatives-workshops-survey/
# Redirected from https://rc.virginia.edu/categories/workshops to https://rc.virginia.edu/categories/workshops/
# Skipping https://rc.virginia.edu/categories/workshops/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/tags/python to https://rc.virginia.edu/tags/python/
# Skipping https://rc.virginia.edu/tags/python/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/tags/bioinformatics to https://rc.virginia.edu/tags/bioinformatics/
# Skipping https://rc.virginia.edu/tags/bioinformatics/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/project/dest/
# Extracted text from https://rc.virginia.edu/project/nicu-bpd/
# Redirected from https://rc.virginia.edu/tags/nicu to https://rc.virginia.edu/tags/nicu/
# Skipping https://rc.virginia.edu/tags/nicu/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/project/nicu-vital-signs/
# Extracted text from https://rc.virginia.edu/project/cardiovascular-genomics/
# Redirected from https://rc.virginia.edu/tags/cphg to https://rc.virginia.edu/tags/cphg/
# Skipping https://rc.virginia.edu/tags/cphg/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/tags/docker to https://rc.virginia.edu/tags/docker/
# Skipping https://rc.virginia.edu/tags/docker/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/singularity/
# Redirected from https://rc.virginia.edu/userinfo/howtos/rivanna/docker-images-on-rivanna to https://rc.virginia.edu/userinfo/howtos/rivanna/docker-images-on-rivanna/
# Extracted text from https://rc.virginia.edu/userinfo/howtos/rivanna/docker-images-on-rivanna/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/containers to https://rc.virginia.edu/userinfo/hpc/software/containers/
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/containers/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/singularity to https://rc.virginia.edu/userinfo/hpc/software/singularity/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/apptainer to https://rc.virginia.edu/userinfo/hpc/software/apptainer/
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/apptainer/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/modules to https://rc.virginia.edu/userinfo/hpc/software/modules/
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/modules/
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/complete-list/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/r to https://rc.virginia.edu/userinfo/hpc/software/r/
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/r/
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/rstudio/
# Redirected from https://rc.virginia.edu/tags/lang to https://rc.virginia.edu/tags/lang/
# Skipping https://rc.virginia.edu/tags/lang/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/code-server/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/code-server/ https:/github.com/cdr/code-server to https://rc.virginia.edu/userinfo/hpc/software/code-server/%20https:/github.com/cdr/code-server
# Redirected from https://rc.virginia.edu/userinfo/hpc/software to https://rc.virginia.edu/userinfo/hpc/software/
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/bioinformatics to https://rc.virginia.edu/userinfo/hpc/software/bioinformatics/
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/bioinformatics/
# Redirected from https://rc.virginia.edu/userinfo/howtos/rivanna/bioinfo-on-rivanna to https://rc.virginia.edu/userinfo/howtos/rivanna/bioinfo-on-rivanna/
# Extracted text from https://rc.virginia.edu/userinfo/howtos/rivanna/bioinfo-on-rivanna/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/bioconda to https://rc.virginia.edu/userinfo/hpc/software/bioconda/
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/bioconda/
# Redirected from https://rc.virginia.edu/categories/bioinformatics to https://rc.virginia.edu/categories/bioinformatics/
# Skipping https://rc.virginia.edu/categories/bioinformatics/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/clara-parabricks/
# Extracted text from https://rc.virginia.edu/userinfo/hpc
 as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/project/simplecache/
# Extracted text from https://rc.virginia.edu/project/sonomicrometry-signal/
# Extracted text from https://rc.virginia.edu/project/transcription-factor/
# Redirected from https://rc.virginia.edu/tags/systems to https://rc.virginia.edu/tags/systems/
# Skipping https://rc.virginia.edu/tags/systems/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/userinfo/k8s/deployments/
# Redirected from https://rc.virginia.edu/categories/containers to https://rc.virginia.edu/categories/containers/
# Skipping https://rc.virginia.edu/categories/containers/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/tags/api to https://rc.virginia.edu/tags/api/
# Skipping https://rc.virginia.edu/tags/api/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/tags/k8s to https://rc.virginia.edu/tags/k8s/
# Skipping https://rc.virginia.edu/tags/k8s/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/tags/hybrid to https://rc.virginia.edu/tags/hybrid/
# Skipping https://rc.virginia.edu/tags/hybrid/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/tags/software-development to https://rc.virginia.edu/tags/software-development/
# Skipping https://rc.virginia.edu/tags/software-development/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/2022/08/accord-community-meeting-august-5-2022/
# Redirected from https://rc.virginia.edu/tags/sensitive-data to https://rc.virginia.edu/tags/sensitive-data/
# Skipping https://rc.virginia.edu/tags/sensitive-data/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/userinfo/storage/sensitive-data/
# Redirected from https://rc.virginia.edu/userinfo/data-transfer to https://rc.virginia.edu/userinfo/data-transfer/
# Extracted text from https://rc.virginia.edu/userinfo/accord/about/
# Extracted text from https://rc.virginia.edu/userinfo/accord/userguide/
# Extracted text from https://rc.virginia.edu/form/accord/
# Redirected from https://rc.virginia.edu/userinfo/accord/environments to https://rc.virginia.edu/userinfo/accord/environments/
# Extracted text from https://rc.virginia.edu/userinfo/accord/environments/
# Redirected from https://rc.virginia.edu/tags/c/c++ to https://rc.virginia.edu/tags/c/c++/
# Skipping https://rc.virginia.edu/tags/c/c++/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/compilers/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/mpi to https://rc.virginia.edu/userinfo/hpc/software/mpi/
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/mpi/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/compilers to https://rc.virginia.edu/userinfo/hpc/software/compilers/
# Redirected from https://rc.virginia.edu/userinfo/howtos/rivanna/mpi-howto to https://rc.virginia.edu/userinfo/howtos/rivanna/mpi-howto/
# Extracted text from https://rc.virginia.edu/userinfo/howtos/rivanna/mpi-howto/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/totalview to https://rc.virginia.edu/userinfo/hpc/software/totalview/
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/totalview/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/totalview/ http:/www.roguewave.com/products-services/totalview to https://rc.virginia.edu/userinfo/hpc/software/totalview/%20http:/www.roguewave.com/products-services/totalview
# Redirected from https://rc.virginia.edu/tags/debugger to https://rc.virginia.edu/tags/debugger/
# Skipping https://rc.virginia.edu/tags/debugger/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/tags/mpi to https://rc.virginia.edu/tags/mpi/
# Skipping https://rc.virginia.edu/tags/mpi/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/spark/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/spark/ https:/spark.apache.org to https://rc.virginia.edu/userinfo/hpc/software/spark/%20https:/spark.apache.org
# Redirected from https://rc.virginia.edu/tags/chem to https://rc.virginia.edu/tags/chem/
# Skipping https://rc.virginia.edu/tags/chem/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/vasp/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/vasp/ http:/www.vasp.at to https://rc.virginia.edu/userinfo/hpc/software/vasp/%20http:/www.vasp.at
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/gromacs/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/gromacs/ http:/www.gromacs.org to https://rc.virginia.edu/userinfo/hpc/software/gromacs/%20http:/www.gromacs.org
# Redirected from https://rc.virginia.edu/tags/container to https://rc.virginia.edu/tags/container/
# Skipping https://rc.virginia.edu/tags/container/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/chemistry/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/abinit to https://rc.virginia.edu/userinfo/hpc/software/abinit/
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/abinit/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/abinit/ https:/www.abinit.org/ to https://rc.virginia.edu/userinfo/hpc/software/abinit/%20https:/www.abinit.org/
# Redirected from https://rc.virginia.edu/categories/chemistry to https://rc.virginia.edu/categories/chemistry/
# Skipping https://rc.virginia.edu/categories/chemistry/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/amber to https://rc.virginia.edu/userinfo/hpc/software/amber/
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/amber/
# Redirected from https://rc.virginia.edu/categories/bio to https://rc.virginia.edu/categories/bio/
# Skipping https://rc.virginia.edu/categories/bio/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/cellranger/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/cellranger/ https:/www.10xgenomics.com/ to https://rc.virginia.edu/userinfo/hpc/software/cellranger/%20https:/www.10xgenomics.com/
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/cellranger-atac/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/cellranger-atac/ https:/support.10xgenomics.com/single-cell-atac/software/pipelines/latest/what-is-cell-ranger-atac to https://rc.virginia.edu/userinfo/hpc/software/cellranger-atac/%20https:/support.10xgenomics.com/single-cell-atac/software/pipelines/latest/what-is-cell-ranger-atac
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/cellprofiler/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/cellprofiler/ https:/github.com/CellProfiler/CellProfiler to https://rc.virginia.edu/userinfo/hpc/software/cellprofiler/%20https:/github.com/CellProfiler/CellProfiler
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/deeplabcut/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/deeplabcut/ https:/github.com/DeepLabCut/DeepLabCut to https://rc.virginia.edu/userinfo/hpc/software/deeplabcut/%20https:/github.com/DeepLabCut/DeepLabCut
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/snakemake/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/snakemake/ https:/snakemake.readthedocs.io to https://rc.virginia.edu/userinfo/hpc/software/snakemake/%20https:/snakemake.readthedocs.io
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/workflow_managers/
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/cromwell/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/cromwell/ http:/cromwell.readthedocs.io/en/develop to https://rc.virginia.edu/userinfo/hpc/software/cromwell/%20http:/cromwell.readthedocs.io/en/develop
# Redirected from https://rc.virginia.edu/userinfo/howtos/rivanna/wdl-bioinformatics to https://rc.virginia.edu/userinfo/howtos/rivanna/wdl-bioinformatics/
# Extracted text from https://rc.virginia.edu/userinfo/howtos/rivanna/wdl-bioinformatics/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/wdltool to https://rc.virginia.edu/userinfo/hpc/software/wdltool/
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/wdltool/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/wdltool/ https:/software.broadinstitute.org/wdl to https://rc.virginia.edu/userinfo/hpc/software/wdltool/%20https:/software.broadinstitute.org/wdl
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/cromwell to https://rc.virginia.edu/userinfo/hpc/software/cromwell/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/bwa to https://rc.virginia.edu/userinfo/hpc/software/bwa/
# Extracted text from https://rc.virginia.edu/userinfo/hpc/software/bwa/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/bwa/ http:/bio-bwa.sourceforge.net/ to https://rc.virginia.edu/userinfo/hpc/software/bwa/%20http:/bio-bwa.sourceforge.net/
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/samtools to https://rc.virginia.edu/userinfo/hpc/software/samtools/
# ...
# Redirected from https://rc.virginia.edu/tags/dedicated-computing to https://rc.virginia.edu/tags/dedicated-computing/
# Skipping https://rc.virginia.edu/tags/dedicated-computing/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/categories/service to https://rc.virginia.edu/categories/service/
# Skipping https://rc.virginia.edu/categories/service/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/categories/status to https://rc.virginia.edu/categories/status/
# Skipping https://rc.virginia.edu/categories/status/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/tags/service to https://rc.virginia.edu/tags/service/
# Skipping https://rc.virginia.edu/tags/service/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/tags/status to https://rc.virginia.edu/tags/status/
# Skipping https://rc.virginia.edu/tags/status/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/userinfo/storage/personal-computing/
# Redirected from https://rc.virginia.edu/tags/personal-computing to https://rc.virginia.edu/tags/personal-computing/
# Skipping https://rc.virginia.edu/tags/personal-computing/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/2021/06/its-home1-directories-unavailable-on-rivanna/
# Extracted text from https://rc.virginia.edu/2025/05/new-nvidia-h200-gpu-node-added-to-afton/
# Extracted text from https://rc.virginia.edu/2024/10/virginia-women-in-hpc-student-lightning-talks-november-12-2024/
# Redirected from https://rc.virginia.edu/tags/va-whpc to https://rc.virginia.edu/tags/va-whpc/
# Skipping https://rc.virginia.edu/tags/va-whpc/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/tags/whpc to https://rc.virginia.edu/tags/whpc/
# Skipping https://rc.virginia.edu/tags/whpc/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/2024/08/virginia-women-in-hpc-building-and-maintaining-supportive-communities/
# Extracted text from https://rc.virginia.edu/2023/10/rcs-data-analytics-center-dac-now-serving-uvas-research-community/
# Redirected from https://rc.virginia.edu/tags/computational-biophysics to https://rc.virginia.edu/tags/computational-biophysics/
# Skipping https://rc.virginia.edu/tags/computational-biophysics/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/2023/09/virginia-women-in-hpc-events-in-september-october/
# Extracted text from https://rc.virginia.edu/2023/03/virginia-women-in-hpc-student-lightning-talks/
# Extracted text from https://rc.virginia.edu/2022/09/virginia-women-in-hpc-women-in-hpc-it-leadership-roles/
# Extracted text from https://rc.virginia.edu/2024/10/afton-cluster-dedicated-to-prof.-john-hawley/
# Extracted text from https://rc.virginia.edu/2024/08/research-computing-open-house-2024/
# Extracted text from https://rc.virginia.edu/userinfo/r_updates/
# Redirected from https://rc.virginia.edu/userinfo/transition_new_r_libraries to https://rc.virginia.edu/userinfo/transition_new_r_libraries/
# Extracted text from https://rc.virginia.edu/userinfo/transition_new_r_libraries/
# Extracted text from https://rc.virginia.edu/userinfo/tools/
# Redirected from https://rc.virginia.edu/userinfo/storage/personal-computing to https://rc.virginia.edu/userinfo/storage/personal-computing/
# Redirected from https://rc.virginia.edu/tags/bart to https://rc.virginia.edu/tags/bart/
# Skipping https://rc.virginia.edu/tags/bart/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/tags/lola to https://rc.virginia.edu/tags/lola/
# Skipping https://rc.virginia.edu/tags/lola/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/userinfo/hpc/software/rstudio to https://rc.virginia.edu/userinfo/hpc/software/rstudio/
# Redirected from https://rc.virginia.edu/userinfo/hpc/ood/fileexplorer to https://rc.virginia.edu/userinfo/hpc/ood/fileexplorer/
# Redirected from https://rc.virginia.edu/2024/07/reinstatement-of-file-purging-of-personal-/scratch-files-on-afton-and-rivanna to https://rc.virginia.edu/2024/07/reinstatement-of-file-purging-of-personal-/scratch-files-on-afton-and-rivanna/
# Redirected from https://rc.virginia.edu/userinfo/hpc/ood/jobcomposer to https://rc.virginia.edu/userinfo/hpc/ood/jobcomposer/
# Extracted text from https://rc.virginia.edu/2025/05/hpc-maintenance-may-27-2025/
# Extracted text from https://rc.virginia.edu/2025/02/hpc-maintenance-schedule-for-2025/
 as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/2020/03/rivanna-software-updates-march-11-2020/
# Extracted text from https://rc.virginia.edu/2020/02/rivanna-maintenance-march-11-2020/
# Extracted text from https://rc.virginia.edu/2019/12/rivanna-maintenance-december-18-2020/
# Extracted text from https://rc.virginia.edu/2019/12/jira-downtime-december-13-2020/
# Extracted text from https://rc.virginia.edu/2024/07/hpc-maintenance-aug-13-2024/
# Extracted text from https://rc.virginia.edu/2024/06/production-release-of-the-afton-hpc-system-july-2-2024/
# Redirected from https://rc.virginia.edu/userinfo/pricing to https://rc.virginia.edu/userinfo/pricing/
# Redirected from https://rc.virginia.edu/form/support-request/?category=Rivanna&request_title=Intro%20to%20HPC%20Orientation%20Session&description=I'd%20like%20to%20reserve%20a%20seat%20for%20the%20next%20"Intro%20to%20HPC"%20orientation%20session%20on%20Wednesday%20August%206,%203-4pm. to https://rc.virginia.edu/form/support-request/?category=Rivanna&request_title=Intro%20to%20HPC%20Orientation%20Session&description=I'd%20like%20to%20reserve%20a%20seat%20for%20the%20next%20%22Intro%20to%20HPC%22%20orientation%20session%20on%20Wednesday%20August%206,%203-4pm.
# Extracted text from https://rc.virginia.edu/form/support-request/?category=Rivanna&request_title=Intro%20to%20HPC%20Orientation%20Session&description=I'd%20like%20to%20reserve%20a%20seat%20for%20the%20next%20%22Intro%20to%20HPC%22%20orientation%20session%20on%20Wednesday%20August%206,%203-4pm.
# Extracted text from https://rc.virginia.edu/userinfo/accord/projects/
# Extracted text from https://rc.virginia.edu/userinfo/accord/faq/
# Redirected from https://rc.virginia.edu/userinfo/faq/rivanna-faq to https://rc.virginia.edu/userinfo/faq/rivanna-faq/
# Redirected from https://rc.virginia.edu/userinfo/howtos/general to https://rc.virginia.edu/userinfo/howtos/general/
# Redirected from https://rc.virginia.edu/userinfo/howtos/rivanna to https://rc.virginia.edu/userinfo/howtos/rivanna/
# Redirected from https://rc.virginia.edu/userinfo/howtos/ivy to https://rc.virginia.edu/userinfo/howtos/ivy/
# Redirected from https://rc.virginia.edu/userinfo/howtos/storage to https://rc.virginia.edu/userinfo/howtos/storage/
# Extracted text from https://rc.virginia.edu/form/support-request/?category=Storage&request_title=Project%20storage%20data%20migration&description=Please%20indicate%20as%20precisely%20as%20possible%20which%20directories%20or%20files%20should%20be%20transferred%20first:
# Extracted text from https://rc.virginia.edu/form/support-request/?category=Storage&request_title=Old%20Project%20Storage:%20File%20List%20Request&description=Please%20send%20me%20a%20list%20of%20my%20files%20on%20old%20Project%20storage
# Extracted text from https://rc.virginia.edu/form/support-request/?category=Storage&request_title=Old%20Project%20Storage:%20File%20List%20Request&description=Please%20send%20me%20a%20list%20of%20my%20files%20on%20old%20Project%20storage.
# Redirected from https://rc.virginia.edu/project?tag=.containers to https://rc.virginia.edu/project/
# Redirected from https://rc.virginia.edu/service/dtc/grants to https://rc.virginia.edu/service/dtc/grants/
# Redirected from https://rc.virginia.edu/service/dac/ai to https://rc.virginia.edu/service/dac/ai/
# Redirected from https://rc.virginia.edu/service/dac/past_awardees to https://rc.virginia.edu/service/dac/past_awardees/
# Extracted text from https://rc.virginia.edu/about/people/huband/
# Extracted text from https://rc.virginia.edu/about/people/boakyedanquah/
# Extracted text from https://rc.virginia.edu/about/people/linehan/
# Extracted text from https://rc.virginia.edu/about/people/prakash/
# Extracted text from https://rc.virginia.edu/about/people/strumpf/
# Extracted text from https://rc.virginia.edu/about/people/triant/
# Redirected from https://rc.virginia.edu/about/people/garrevenkata to https://rc.virginia.edu/about/people/garrevenkata/
# Extracted text from https://rc.virginia.edu/about/people/garrevenkata/
# Redirected from https://rc.virginia.edu/about/people/khan to https://rc.virginia.edu/about/people/khan/
# Extracted text from https://rc.virginia.edu/about/people/khan/
# Redirected from https://rc.virginia.edu/about/people/kureishi to https://rc.virginia.edu/about/people/kureishi/
# Extracted text from https://rc.virginia.edu/about/people/kureishi/
# Redirected from https://rc.virginia.edu/about/people/lin to https://rc.virginia.edu/about/people/lin/
# Extracted text from https://rc.virginia.edu/about/people/lin/
# Redirected from https://rc.virginia.edu/about/people/mistele to https://rc.virginia.edu/about/people/mistele/
# Extracted text from https://rc.virginia.edu/about/people/mistele/
# Redirected from https://rc.virginia.edu/about/people/shankar to https://rc.virginia.edu/about/people/shankar/
# Extracted text from https://rc.virginia.edu/about/people/shankar/
# Redirected from https://rc.virginia.edu/about/people/siadaty to https://rc.virginia.edu/about/people/siadaty/
# Extracted text from https://rc.virginia.edu/about/people/siadaty/
# Redirected from https://rc.virginia.edu/about/people/tran to https://rc.virginia.edu/about/people/tran/
# Extracted text from https://rc.virginia.edu/about/people/tran/
# Redirected from https://rc.virginia.edu/about/people/vu to https://rc.virginia.edu/about/people/vu/
# Extracted text from https://rc.virginia.edu/about/people/vu/
# Extracted text from https://rc.virginia.edu/about/people/andino/
# Extracted text from https://rc.virginia.edu/about/people/duy/
# Extracted text from https://rc.virginia.edu/about/people/parece/
# Extracted text from https://rc.virginia.edu/about/people/siller/
# Extracted text from https://rc.virginia.edu/about/people/sun/
# Extracted text from https://rc.virginia.edu/about/people/eubanks/
# Extracted text from https://rc.virginia.edu/about/people/galitz/
# Extracted text from https://rc.virginia.edu/about/people/kim/
# Extracted text from https://rc.virginia.edu/about/people/jpark/
# Extracted text from https://rc.virginia.edu/about/people/periyasamy/
# Extracted text from https://rc.virginia.edu/about/people/quist/
# Extracted text from https://rc.virginia.edu/about/people/tomar/
# Extracted text from https://rc.virginia.edu/about/people/vo/
# Extracted text from https://rc.virginia.edu/about/people/hongyan/
# Extracted text from https://rc.virginia.edu/about/people/xu/
# Redirected from https://rc.virginia.edu/tags/search to https://rc.virginia.edu/tags/search/
# Skipping https://rc.virginia.edu/tags/search/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/categories/forms to https://rc.virginia.edu/categories/forms/
# Skipping https://rc.virginia.edu/categories/forms/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/form/combined-request-form/
# Redirected from https://rc.virginia.edu/tags/signup to https://rc.virginia.edu/tags/signup/
# Skipping https://rc.virginia.edu/tags/signup/ as it does not contain exactly one article
# Extracted text from https://rc.virginia.edu/signup/
# Redirected from https://rc.virginia.edu/tags/support to https://rc.virginia.edu/tags/support/
# Skipping https://rc.virginia.edu/tags/support/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/categories/support to https://rc.virginia.edu/categories/support/
# Skipping https://rc.virginia.edu/categories/support/ as it does not contain exactly one article
# Redirected from https://rc.virginia.edu/userinfo/storage/data-sensitivity to https://rc.virginia.edu/userinfo/storage/data-sensitivity/
# Redirected from https://rc.virginia.edu/userinfo/storage/research-project to https://rc.virginia.edu/userinfo/storage/research-project/
# Redirected from https://rc.virginia.edu/userinfo/storage/research-standard to https://rc.virginia.edu/userinfo/storage/research-standard/
# Extracted text from https://rc.virginia.edu/form/support-request/?category=Rivanna&request_title=Dedicated%20Computing
# Skipping https://rc.virginia.edu/post/ as it does not contain exactly one article
# Skipping https://rc.virginia.edu/post/page/2/ as it does not contain exactly one article
# Skipping https://rc.virginia.edu/post/page/3/ as it does not contain exactly one article
# Skipping https://rc.virginia.edu/post/page/4/ as it does not contain exactly one article

# %%
documents += crawl("https://learning.rc.virginia.edu/")
# Out:
# Skipping https://learning.rc.virginia.edu/ as it does not contain exactly one article
# Skipping https://learning.rc.virginia.edu/courses/ as it does not contain exactly one article
# Skipping https://learning.rc.virginia.edu/tutorials/ as it does not contain exactly one article
# Skipping https://learning.rc.virginia.edu/authors/ as it does not contain exactly one article
# Skipping https://learning.rc.virginia.edu/author/ruoshi-sun/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/tutorials/building-running-c-cpp-fortran/
# Skipping https://learning.rc.virginia.edu/author/katherine-holcomb/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/tutorials/hpc-intro/
# Skipping https://learning.rc.virginia.edu/author/jacalyn-huband/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/tutorials/deep-learning-distributed/
# Skipping https://learning.rc.virginia.edu/author/ahmad-sheikhzada/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/tutorials/rio-intro/
# Skipping https://learning.rc.virginia.edu/author/paul-orndorff/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/notes/rio-intro/
# Skipping https://learning.rc.virginia.edu/category/hpc/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/courses/containers-for-hpc/
# Extracted text from https://learning.rc.virginia.edu/courses/containers-for-hpc/intro/
# Extracted text from https://learning.rc.virginia.edu/courses/containers-for-hpc/using/
# Extracted text from https://learning.rc.virginia.edu/courses/containers-for-hpc/building-apptainer/
# Extracted text from https://learning.rc.virginia.edu/courses/containers-for-hpc/building-docker/
# Extracted text from https://learning.rc.virginia.edu/courses/containers-for-hpc/minimal/
# Skipping https://learning.rc.virginia.edu/tag/containers/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/tutorials/containers/
# Skipping https://learning.rc.virginia.edu/author/christina-gancayco/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/tutorials/globus-data-transfer/
# Skipping https://learning.rc.virginia.edu/category/data-transfer/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/tutorials/working-with-files/
# Skipping https://learning.rc.virginia.edu/category/open-ondemand/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/tutorials/connecting-to-hpc/
# Skipping https://learning.rc.virginia.edu/category/programming/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/building/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/setting_up/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/linkers_libraries/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/make/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/variables/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/declarations/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/characters/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/encodings_strings/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/statements/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/type_conversions/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/operators/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/conditionals/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/project1/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/loops/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/c_arrays/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/pointers_mem/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/containers_templates/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/project2/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/boost/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/console_io/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/file_io/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/advanced_io/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/project3/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/subprograms/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/subprogram_args/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/project4/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/scope/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/enums/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/project5/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/structs/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/classes/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/class_structure/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/inheritance/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/project6/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/polymorphism/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/error_handling/
# Extracted text from https://learning.rc.virginia.edu/courses/cpp-introduction/project7/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/fractions.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/exceptions.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/static_assert.cxx
# Redirected from https://learning.rc.virginia.edu/courses/cpp-introduction/project5 to https://learning.rc.virginia.edu/courses/cpp-introduction/project5/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/birdclass/birdData.h
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/birdclass/birdData.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/birdclass/birdstats.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/inheritance.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/child_constructor.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/inherit_chain.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/constructor_chain.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/illegal_access.cxx
# Redirected from https://learning.rc.virginia.edu/courses/cpp-introduction/inheritance to https://learning.rc.virginia.edu/courses/cpp-introduction/inheritance/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/access_demo.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/class_struct_example/Employee.h
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/class_struct_example/Employee.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/class_struct_example/employees.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/employees.cxx
# Redirected from https://learning.rc.virginia.edu/courses/cpp-introduction/classes to https://learning.rc.virginia.edu/courses/cpp-introduction/classes/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/data/vabirds.csv
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/read_bird_data.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/birdstruct/birdData.h
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/birdstruct/birdData.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/birdstruct/birdstats.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/enum.cxx
# Redirected from https://learning.rc.virginia.edu/courses/cpp-introduction/structs to https://learning.rc.virginia.edu/courses/cpp-introduction/structs/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/scope.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/namespace.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/nestednamespace.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/namespacescope.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/data/bodyfat.csv
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/stats.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/bmistats.h
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/bmistats.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/bmi.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/subroutine.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/pointer_pass.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/trap.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/printme.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/default_args.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/function1.cxx
# Redirected from https://learning.rc.virginia.edu/courses/cpp-introduction/linkers_libraries to https://learning.rc.virginia.edu/courses/cpp-introduction/linkers_libraries/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/function2.h
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/function2.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/data/cpi.csv
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/inflation.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/cl.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/read_csv.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/read_cpi.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/read_write_csv.cxx
# Redirected from https://learning.rc.virginia.edu/courses/cpp-introduction/console_io to https://learning.rc.virginia.edu/courses/cpp-introduction/console_io/
# Redirected from https://learning.rc.virginia.edu/courses/cpp-introduction/advanced_io to https://learning.rc.virginia.edu/courses/cpp-introduction/advanced_io/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/read_write_file.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/read_cin.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/out_manip.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/print_pi.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/kangaroo.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/makefile.windows_boost
# Redirected from https://learning.rc.virginia.edu/courses/cpp-introduction/make to https://learning.rc.virginia.edu/courses/cpp-introduction/make/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/boost_example.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/makefile.linux_mac_boost
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/boost_array.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/splitter.cxx
# Redirected from https://learning.rc.virginia.edu/courses/cpp-introduction/scope to https://learning.rc.virginia.edu/courses/cpp-introduction/scope/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/std_vector.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/vector.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/pointers.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/twod.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/leaker.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/fixed_leaker.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/simple_array.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/c_arrays.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/loop_scope.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/while_demo.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/do_while.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/loops.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/day_of_week.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/if_demo.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/nfc.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/testmod.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/expressions.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/conditional_operators.cxx
# Redirected from https://learning.rc.virginia.edu/courses/cpp-introduction/pointers_mem to https://learning.rc.virginia.edu/courses/cpp-introduction/pointers_mem/
# Redirected from https://learning.rc.virginia.edu/courses/cpp-introduction/polymorphism to https://learning.rc.virginia.edu/courses/cpp-introduction/polymorphism/
# Redirected from https://learning.rc.virginia.edu/courses/cpp-introduction/file_io to https://learning.rc.virginia.edu/courses/cpp-introduction/file_io/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/strings.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/solns/strings.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/cstr.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/buffer_oflow.cxx
# Redirected from https://learning.rc.virginia.edu/courses/cpp-introduction/encodings_strings to https://learning.rc.virginia.edu/courses/cpp-introduction/encodings_strings/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/Makefile
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/codes/makemake
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/netcdf_example/simple_xy_wr.cpp
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/netcdf_example/Makefile
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/compiler_example/example.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/compiler_example/adder.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/cpp-introduction/compiler_example/adder.h
# Redirected from https://learning.rc.virginia.edu/courses/cpp-introduction/building to https://learning.rc.virginia.edu/courses/cpp-introduction/building/
# Skipping https://learning.rc.virginia.edu/tag/programming/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/parallel_basics/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/parallel_strategies/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/performance_analysis/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/parallel_hardware/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/parallel_software_approaches/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_memory_programming/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_programs/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_buffers/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_basics/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_setup/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_build_run/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_timing/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_random_walk/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_domain_decomp/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_global1/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_global2/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_global3/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_reductions/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_project_set1/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_p2p1/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_sendmodes/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_standardsends/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_recvstatus/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_nearest_neighbor/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_sendrecv/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_project_set2/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_array_buffers/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_oned_division/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_ghost_zones/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_halo_exchange/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_memory_layouts/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_halo_sendrecv/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_example_applications/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_heated_plate/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_jacobi_method/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_project_set3/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_nonblocking_comms/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_nonblocking_completion/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_nonblocking_exchange/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_higher_dims/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_types/
# Extracted text from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_vector_type/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/mpi_vector_type.cxx
# Redirected from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_types to https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_types/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/mpi_vector_type.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/mpi_vector_type.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/mpi_nonblock_halo.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/mpi_nonblock_halo.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/mpi_nonblock_halo.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/scripts/contour.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/heatedplate.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/heatedplate.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/heatedplate.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpiheatedplate.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpiheatedplate.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpiheatedplate.py
# Redirected from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_oned_division to https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_oned_division/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpi_halo_exchange.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpi_halo_exchange.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpi_halo_exchange.py
# Redirected from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_array_buffers to https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_array_buffers/
# Redirected from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_halo_exchange to https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_halo_exchange/
# Redirected from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_domain_decomp to https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_domain_decomp/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpi_send_array.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpi_send_array.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpi_send_array.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/ring.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/ring.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/ring.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/send_recv_rank.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/send_recv_rank.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/send_recv_rank.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/manager_worker_stub.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/manager_worker_stub.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/manager_worker.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/manager_worker.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/manager_worker.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/mpi_sendrecv.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/mpi_sendrecv.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/mpi_sendrecv.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/exchange_deadlock.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/exchange_deadlock.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/exchange_deadlock.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/exchange_unsafe.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/exchange_unsafe.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/exchange_unsafe.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/exchange_safe.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/exchange_safe.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/exchange_safe.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/send_recv_stat.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/send_recv_stat.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/send_recv_stat.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/send_recv.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/send_recv.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/send_recv.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/montecarlo_pi.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/montecarlo_pi.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/montecarlo_pi.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpimontecarlo_pi.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpimontecarlo_pi.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpimontecarlo_pi.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/trap.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/trap.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/trap.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpitrap.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpitrap.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpitrap.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/find_max.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/find_max.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/find_max.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpifind_max.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpifind_max.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpifind_max.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/reduce.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/reduce.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/reduce.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpirandom_walk_red.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpirandom_walk_red.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpirandom_walk_red.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/bcast_ex.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/bcast_ex.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/bcast_ex.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/allreduce.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/allreduce.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/allreduce.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/allgather.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/allgather.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/allgather.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/gather.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/gather.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/gather.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/gatherv.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/gatherv.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/gatherv.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/bcast.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/bcast.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/bcast.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/scatter.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/scatter.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/scatter.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/scatterv.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/scatterv.f90
# Redirected from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/parallel_basics to https://learning.rc.virginia.edu/courses/parallel-computing-introduction/parallel_basics/
# Redirected from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_project_set1 to https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_project_set1/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpifind_max_dd.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpifind_max_dd.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpifind_max_dd.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/random_walk.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/random_walk.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/random_walk.py
# Redirected from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/performance_analysis to https://learning.rc.virginia.edu/courses/parallel-computing-introduction/performance_analysis/
# Redirected from https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_random_walk to https://learning.rc.virginia.edu/courses/parallel-computing-introduction/distributed_mpi_random_walk/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpirandom_walk_timed.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpirandom_walk_timed.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/solns/mpirandom_walk_timed.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/mpi1.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/mpi1.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/mpi1.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/parallel-computing-introduction/codes/mpi4py_ex.py
# Skipping https://learning.rc.virginia.edu/tag/parallel_programming/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/tutorials/benchmark-parallel-programs/
# Skipping https://learning.rc.virginia.edu/category/parallel-programming/ as it does not contain exactly one article
# Skipping https://learning.rc.virginia.edu/category/gpu/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/tutorials/gpu-applications-rivanna/
# Extracted text from https://learning.rc.virginia.edu/notes/gpu-applications-rivanna/
# Skipping https://learning.rc.virginia.edu/tag/gpu/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/tutorials/rapids/
# Skipping https://learning.rc.virginia.edu/category/python/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/courses/pytorch-hpc/
# Extracted text from https://learning.rc.virginia.edu/courses/pytorch-hpc/overview/
# Extracted text from https://learning.rc.virginia.edu/courses/pytorch-hpc/simple_nn/
# Extracted text from https://learning.rc.virginia.edu/courses/pytorch-hpc/gpu/
# Extracted text from https://learning.rc.virginia.edu/courses/pytorch-hpc/transfer/
# Extracted text from https://learning.rc.virginia.edu/courses/pytorch-hpc/optimize/
# Extracted text from https://learning.rc.virginia.edu/courses/pytorch-hpc/project/
# Extracted text from https://learning.rc.virginia.edu/notes/benchmark-parallel-programs/
# Extracted text from https://learning.rc.virginia.edu/courses/python-high-performance/
# Extracted text from https://learning.rc.virginia.edu/courses/python-high-performance/profiling-timing/
# Extracted text from https://learning.rc.virginia.edu/courses/python-high-performance/serial-optimization/
# Extracted text from https://learning.rc.virginia.edu/courses/python-high-performance/compiled_code/
# Extracted text from https://learning.rc.virginia.edu/courses/python-high-performance/multiprocessing/
# Extracted text from https://learning.rc.virginia.edu/courses/python-high-performance/distributed-parallelization/
# Extracted text from https://learning.rc.virginia.edu/courses/python-high-performance/mpi-parallelization/
# Extracted text from https://learning.rc.virginia.edu/courses/python-high-performance/gpu_acceleration/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/cupy_example.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/pycuda_example.py
# Redirected from https://learning.rc.virginia.edu/courses/python-high-performance/compiled_code to https://learning.rc.virginia.edu/courses/python-high-performance/compiled_code/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/pycuda_numba.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/numba_vectorize.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/numba_vectorize_todevice.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/numba_cuda_example.py
# Redirected from https://learning.rc.virginia.edu/courses/parallel-computing-introduction to https://learning.rc.virginia.edu/courses/parallel-computing-introduction/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/MonteCarloPiMPI.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/pympi.slurm
# Redirected from https://learning.rc.virginia.edu/courses/python-high-performance/multiprocessing to https://learning.rc.virginia.edu/courses/python-high-performance/multiprocessing/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/dask_df_mpi.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/run_dask_mpi.slurm
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/dask_viz.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/dask_df_example.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/dask_delayed.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/mpstarmap.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/MonteCarloPiMC.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/pimc.sh
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/fractions.f90
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/arith.c
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/arith.h
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/build_arith.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/fractions.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/fractions.h
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/wrap_fractions.cxx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/tasks.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/integrate_cyf.pyx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/setup.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/MonteCarloPi.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/replace_forloop_comp.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/loops.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/aops.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/replace_forloop.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-high-performance/codes/fibonacci.py
# Redirected from https://learning.rc.virginia.edu/courses/python-high-performance/serial-optimization to https://learning.rc.virginia.edu/courses/python-high-performance/serial-optimization/
# Redirected from https://learning.rc.virginia.edu/courses/python-high-performance/distributed-parallelization to https://learning.rc.virginia.edu/courses/python-high-performance/distributed-parallelization/
# Skipping https://learning.rc.virginia.edu/tag/python/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/tutorials/biopython/
# Skipping https://learning.rc.virginia.edu/author/karsten-siller/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/courses/fiji-image-processing/fiji-omero/
# Extracted text from https://learning.rc.virginia.edu/courses/fiji-image-processing/
# Extracted text from https://learning.rc.virginia.edu/courses/fiji-image-processing/introduction/
# Extracted text from https://learning.rc.virginia.edu/courses/fiji-image-processing/scripting/
# Skipping https://learning.rc.virginia.edu/tag/image_processing/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/tutorials/matlab-image-processing/
# Skipping https://learning.rc.virginia.edu/category/image-processing/ as it does not contain exactly one article
# Skipping https://learning.rc.virginia.edu/category/matlab/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/courses/matlab-programming/
# Extracted text from https://learning.rc.virginia.edu/courses/matlab-programming/fundamentals/
# Extracted text from https://learning.rc.virginia.edu/courses/matlab-programming/getting_started/
# Extracted text from https://learning.rc.virginia.edu/courses/matlab-programming/effective_programming/
# Extracted text from https://learning.rc.virginia.edu/courses/matlab-programming/techniques/
# Skipping https://learning.rc.virginia.edu/tag/matlab/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/notes/matlab-parallel-programming/
# Extracted text from https://learning.rc.virginia.edu/notes/matlab-parallel-programming/matlab-parallel-programming_1/
# Extracted text from https://learning.rc.virginia.edu/notes/matlab-parallel-programming/matlab-parallel-programming_3/
# Extracted text from https://learning.rc.virginia.edu/notes/matlab-parallel-programming/matlab-parallel-programming_2/
# Extracted text from https://learning.rc.virginia.edu/notes/matlab-parallel-programming/matlab-parallel-programming_4/
# Extracted text from https://learning.rc.virginia.edu/notes/matlab-parallel-programming/matlab-parallel-programming_5/
# Extracted text from https://learning.rc.virginia.edu/notes/matlab-parallel-programming/matlab-parallel-programming_6/
# Extracted text from https://learning.rc.virginia.edu/notes/matlab-parallel-programming/matlab-parallel-programming_7/
# Extracted text from https://learning.rc.virginia.edu/notes/matlab-parallel-programming/out/
# Skipping https://learning.rc.virginia.edu/tag/parallel_computing/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/tutorials/matlab-statistics/
# Skipping https://learning.rc.virginia.edu/author/uva-research-computing/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/tutorials/git-intro/
# Skipping https://learning.rc.virginia.edu/category/git/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/notes/git-intro/
# Skipping https://learning.rc.virginia.edu/tag/git/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/tutorials/deep-learning-hpc/
# Skipping https://learning.rc.virginia.edu/category/machine-learning/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/tutorials/matlab-data-science/
# Skipping https://learning.rc.virginia.edu/author/ed-hall/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/tutorials/matlab-optimization/
# Extracted text from https://learning.rc.virginia.edu/notes/matlab-optimization/
# Extracted text from https://learning.rc.virginia.edu/tutorials/matlab-parallel/
# Skipping https://learning.rc.virginia.edu/category/parallel-computing/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/courses/introduction_to_mpi/
# Extracted text from https://learning.rc.virginia.edu/courses/introduction_to_mpi/part_1/
# ...
# Extracted text from https://learning.rc.virginia.edu/courses/python-introduction/assertions/
# Extracted text from https://learning.rc.virginia.edu/courses/python-introduction/unit_test/
# Extracted text from https://learning.rc.virginia.edu/courses/python-introduction/resources/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/scripts/dow_tests.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/scripts/assert_it.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/scripts/dow_buggy.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/exercises/dow.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/data/VaGoldfinch.txt
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/solns/proj_set_5/birds.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/data/movies.txt
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/solns/proj_set_5/movies.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/solns/proj_set_5/fractions.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/scripts/zoo.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/scripts/points.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/exercises/points.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/scripts/points_printer.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/scripts/mymodule_private.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/scripts/privateclass.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/scripts/person_module.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/scripts/mymodule.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/solns/proj_set_4/basketball_data.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/solns/proj_set_4/pivot_table_example.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/data/eighthr.data
# Skipping non-HTML URL: https://learning.rc.virginia.edu/data/eighthr.names
# Skipping non-HTML URL: https://learning.rc.virginia.edu/data/cigarette-smoking-behaviour-2018-census.csv
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/solns/proj_set_4/cigarette_smoking_nz.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/data/cville_2017_april.xlsx
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/solns/proj_set_4/cville_2017_apr_pandas.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/data/MikeTroutData.csv
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/scripts/pandas_plot.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/scripts/multiplot.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/scripts/barchart.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/scripts/plot_table.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/exercises/bmi_pandas.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/data/weather.csv
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/exercises/iris.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/scripts/pandas_series.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/exercises/fake_weather_data.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/solns/proj_set_3/numpy_basics.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/solns/proj_set_3/inflation.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/solns/proj_set_3/bmistats.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/data/cville_2017_april.csv
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/solns/proj_set_3/cville_2017_apr.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/exercises/scipy_img.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/scripts/scatter_plot.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/scripts/subplots.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/scripts/streamlines.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/scripts/contour.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/scripts/surface.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/scripts/seaborn_demo.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/scripts/seaborn_demo2.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/exercises/bmi_code.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/exercises/numpy_arrays.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/data/numbers.csv
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/exercises/exceptions_example.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/scripts/read_file_ex.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/exercises/readlines_demo.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/exercises/polynomial.py
# Redirected from https://learning.rc.virginia.edu/courses/python-introduction/exceptions to https://learning.rc.virginia.edu/courses/python-introduction/exceptions/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/exercises/file_fiddling.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/exercises/user_input_bmi.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/solns/proj_set_2/sum_to_N.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/solns/proj_set_2/sums_table.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/data/us-state-capitals.csv
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/solns/proj_set_2/state_capitals.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/data/HIV.txt
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/solns/proj_set_2/DNA.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/data/Example.txt
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/solns/proj_set_2/scramble_text.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/exercises/dictionary_demo.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/exercises/create_dictionary.py
# Redirected from https://learning.rc.virginia.edu/courses/python-introduction/classes to https://learning.rc.virginia.edu/courses/python-introduction/classes/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/exercises/string_functions.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/scripts/rooter.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/exercises/functionals.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/scripts/args_kwargs.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/exercises/user_bmi_function.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/solns/proj_set_1/temperature_list.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/solns/proj_set_1/temperature_loop.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/solns/proj_set_1/temperature_cond_loop.py
# Redirected from https://learning.rc.virginia.edu/courses/python-introduction/formatted_io to https://learning.rc.virginia.edu/courses/python-introduction/formatted_io/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/solns/proj_set_1/collatz.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/solns/proj_set_1/base_convert.py
# Redirected from https://learning.rc.virginia.edu/courses/python-introduction/modules to https://learning.rc.virginia.edu/courses/python-introduction/modules/
# Redirected from https://learning.rc.virginia.edu/courses/python-introduction/numpy_matplotlib_scipy to https://learning.rc.virginia.edu/courses/python-introduction/numpy_matplotlib_scipy/
# Redirected from https://learning.rc.virginia.edu/courses/python-introduction/for_loops to https://learning.rc.virginia.edu/courses/python-introduction/for_loops/
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/exercises/sum_to_N_while.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/exercises/sum_to_N.py
# Skipping non-HTML URL: https://learning.rc.virginia.edu/courses/python-introduction/exercises/simple_bmi.py
# Redirected from https://learning.rc.virginia.edu/courses/python-introduction/sequences to https://learning.rc.virginia.edu/courses/python-introduction/sequences/
# Redirected from https://learning.rc.virginia.edu/courses/python-introduction/strings to https://learning.rc.virginia.edu/courses/python-introduction/strings/
# Redirected from https://learning.rc.virginia.edu/courses/python-introduction/expressions_statements to https://learning.rc.virginia.edu/courses/python-introduction/expressions_statements/
# Redirected from https://learning.rc.virginia.edu/courses/python-introduction/packages_environments to https://learning.rc.virginia.edu/courses/python-introduction/packages_environments/
# Redirected from https://learning.rc.virginia.edu/courses/python-introduction/jupyter to https://learning.rc.virginia.edu/courses/python-introduction/jupyter/
# Redirected from https://learning.rc.virginia.edu/courses/python-introduction/ides to https://learning.rc.virginia.edu/courses/python-introduction/ides/
# Redirected from https://learning.rc.virginia.edu/courses/python-high-performance to https://learning.rc.virginia.edu/courses/python-high-performance/
# Extracted text from https://learning.rc.virginia.edu/notes/rapids/
# Skipping https://learning.rc.virginia.edu/tag/c-/ as it does not contain exactly one article
# Skipping https://learning.rc.virginia.edu/tag/programming/page/2/ as it does not contain exactly one article
# Skipping https://learning.rc.virginia.edu/category/programming/page/2/ as it does not contain exactly one article
# Skipping https://learning.rc.virginia.edu/tag/data_transfer/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/notes/globus-data-transfer/
# Extracted text from https://learning.rc.virginia.edu/notes/globus-data-transfer/overview/
# Extracted text from https://learning.rc.virginia.edu/notes/globus-data-transfer/advantages/
# Extracted text from https://learning.rc.virginia.edu/notes/globus-data-transfer/terminology/
# Extracted text from https://learning.rc.virginia.edu/notes/globus-data-transfer/logging_in/
# Extracted text from https://learning.rc.virginia.edu/notes/globus-data-transfer/installation/
# Extracted text from https://learning.rc.virginia.edu/notes/globus-data-transfer/setup/
# Extracted text from https://learning.rc.virginia.edu/notes/globus-data-transfer/add_locations/
# Extracted text from https://learning.rc.virginia.edu/notes/globus-data-transfer/transferring_files/
# Extracted text from https://learning.rc.virginia.edu/notes/globus-data-transfer/transfer_setup_folders/
# Extracted text from https://learning.rc.virginia.edu/notes/globus-data-transfer/transfer_select_folders/
# Extracted text from https://learning.rc.virginia.edu/notes/globus-data-transfer/transfer_start/
# Extracted text from https://learning.rc.virginia.edu/notes/globus-data-transfer/monitor/
# Extracted text from https://learning.rc.virginia.edu/notes/globus-data-transfer/share/
# Extracted text from https://learning.rc.virginia.edu/notes/globus-data-transfer/troubleshooting/
# Skipping https://learning.rc.virginia.edu/tag/globus/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/notes/containers/
# Extracted text from https://learning.rc.virginia.edu/notes/containers/overview/
# Extracted text from https://learning.rc.virginia.edu/notes/containers/overview-purpose/
# Extracted text from https://learning.rc.virginia.edu/notes/containers/overview-vms/
# Extracted text from https://learning.rc.virginia.edu/notes/containers/overview-services/
# Extracted text from https://learning.rc.virginia.edu/notes/containers/basics/
# Extracted text from https://learning.rc.virginia.edu/notes/containers/basics-example/
# Extracted text from https://learning.rc.virginia.edu/notes/containers/basics-webapps/
# Extracted text from https://learning.rc.virginia.edu/notes/containers/basics-dockerfile/
# Extracted text from https://learning.rc.virginia.edu/notes/containers/shinyapp/
# Extracted text from https://learning.rc.virginia.edu/notes/containers/shinyapp-dockerfile/
# Extracted text from https://learning.rc.virginia.edu/notes/containers/shinyapp-dockerbuild/
# Extracted text from https://learning.rc.virginia.edu/notes/containers/shinyapp-debugging/
# Extracted text from https://learning.rc.virginia.edu/notes/containers/shinyapp-dockerpush/
# Extracted text from https://learning.rc.virginia.edu/notes/containers/github/
# Extracted text from https://learning.rc.virginia.edu/notes/containers/github-newrepo/
# Extracted text from https://learning.rc.virginia.edu/notes/containers/github-commands/
# Extracted text from https://learning.rc.virginia.edu/notes/containers/github-actions/
# Skipping https://learning.rc.virginia.edu/category/hpc/page/2/ as it does not contain exactly one article
# Skipping https://learning.rc.virginia.edu/category/hpc/page/3/ as it does not contain exactly one article
# Redirected from https://learning.rc.virginia.edu/notes/rio-intro to https://learning.rc.virginia.edu/notes/rio-intro/
# Extracted text from https://learning.rc.virginia.edu/notes/deep-learning-distributed/
# Extracted text from https://learning.rc.virginia.edu/notes/building-running-c-cpp-fortran/
# Skipping https://learning.rc.virginia.edu/tag/c/ as it does not contain exactly one article
# Skipping https://learning.rc.virginia.edu/author/ab/ as it does not contain exactly one article
# Extracted text from https://learning.rc.virginia.edu/notes/pytorch-hpc/
# Skipping https://learning.rc.virginia.edu/author/camden-duy/ as it does not contain exactly one article
# Skipping https://learning.rc.virginia.edu/authors/page/2/ as it does not contain exactly one article
# Skipping https://learning.rc.virginia.edu/author/will-rosenow/ as it does not contain exactly one article
# Skipping https://learning.rc.virginia.edu/courses/page/2/ as it does not contain exactly one article
# Redirected from https://learning.rc.virginia.edu/landing to https://learning.rc.virginia.edu/landing/
# Skipping https://learning.rc.virginia.edu/landing/ as it does not contain exactly one article
# Redirected from https://learning.rc.virginia.edu/tutorials to https://learning.rc.virginia.edu/tutorials/
# Redirected from https://learning.rc.virginia.edu/courses to https://learning.rc.virginia.edu/courses/

# %%
print(len(documents))
# Out:
# 915

# %%
from langchain.schema import Document

website_documents = []
for i, (url, doc) in enumerate(documents.items()):
    text = doc["text"]
    metadata = doc["metadata"]
    if not text.strip():
        print(f"Skipping empty document for URL: {url}")
        continue
    doc = Document(
        page_content=text,
        metadata={
            "source_type": metadata["source_type"],
            "source": metadata["source"],
            "chunk_number": metadata["chunk_number"],
            "tags": str(metadata["tags"]),
            "date_updated": metadata.get("date_updated", None),
        }
    )
    website_documents.append(doc)

# %%
# for doc in website_documents[:5]:
#     print(f"Document source: {doc.metadata['source']}, tags: {doc.metadata['tags']}")
#     print(f"Document text: {doc.page_content[:100]}...")  # Print first 100 characters of the text

print(website_documents[500].page_content)
# Out:
# # [Mission](https://rc.virginia.edu/about/mission/)
#
# Research Computing empowers UVA researchers to achieve more with cutting-edge computational resources. Our support team strives to create innovative solutions for researchers who need
# help solving complex optimization, parallelization, workflow, and data analysis issues. We build and maintain the University's best computing platforms while educating the next
# generation of researchers on the power of advanced computing.

# %%
def document_to_id(doc):
    return f"{doc.metadata['source_type']}_{doc.metadata['source']}_{doc.metadata['chunk_number']}".replace("/", "_").replace(":", "_").replace("?", "_").replace("#", "_")

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.retrievers import ParentDocumentRetriever
from langchain_community.storage import SQLStore
from langchain.storage._lc_store import create_kv_docstore

DOCUMENT_STORE_NAMESPACE = "full_documents"

child_splitter = RecursiveCharacterTextSplitter(
    chunk_size=400,
    chunk_overlap=200,
    length_function=len,
)

parent_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=500,
    length_function=len,
)

sql_store = SQLStore(
    namespace=DOCUMENT_STORE_NAMESPACE,
    db_url=CONNECTION_STRING,
)
doc_store = create_kv_docstore(sql_store)
sql_store.create_schema()

retriever = ParentDocumentRetriever(
    vectorstore=vector_store,
    docstore=doc_store,
    child_splitter=child_splitter,
    # parent_splitter=parent_splitter,
)

# %%
BATCH_SIZE = 10

to_add = [doc for doc in website_documents if sql_store.mget(keys=[document_to_id(doc)])[0] is None]
print(f"Documents to add: {len(to_add)}/{len(website_documents)} total documents")

# Add documents to the vector store in batches
for i in range(0, len(to_add), BATCH_SIZE):
    batch = to_add[i:i + BATCH_SIZE]
    # retriever.add_documents(documents=batch, ids=[document_to_id(x) for doc in batch for x in parent_splitter.split_documents([doc])])
    retriever.add_documents(documents=batch, ids=[document_to_id(doc) for doc in batch])
    print(f"Processed batch {i // BATCH_SIZE + 1}/{(len(to_add) + BATCH_SIZE - 1) // BATCH_SIZE}")
# Out:
# Documents to add: 540/915 total documents
# Processed batch 1/54
# Processed batch 2/54
# Processed batch 3/54
# Processed batch 4/54
# Processed batch 5/54
# Processed batch 6/54
# Processed batch 7/54
# Processed batch 8/54
# Processed batch 9/54
# Processed batch 10/54
# Processed batch 11/54
# Processed batch 12/54
# Processed batch 13/54
# Processed batch 14/54
# Processed batch 15/54
# Processed batch 16/54
# Processed batch 17/54
# Processed batch 18/54
# Processed batch 19/54
# Processed batch 20/54
# Processed batch 21/54
# Processed batch 22/54
# Processed batch 23/54
# Processed batch 24/54
# Processed batch 25/54
# Processed batch 26/54
# Processed batch 27/54
# Processed batch 28/54
# Processed batch 29/54
# Processed batch 30/54
# Processed batch 31/54
# Processed batch 32/54
# Processed batch 33/54
# Processed batch 34/54
# Processed batch 35/54
# Processed batch 36/54
# Processed batch 37/54
# Processed batch 38/54
# Processed batch 39/54
# Processed batch 40/54
# Processed batch 41/54
# Processed batch 42/54
# Processed batch 43/54
# Processed batch 44/54
# Processed batch 45/54
# Processed batch 46/54
# Processed batch 47/54
# Processed batch 48/54
# Processed batch 49/54
# Processed batch 50/54
# Processed batch 51/54
# Processed batch 52/54
# Processed batch 53/54
# Processed batch 54/54

# %%
from ollama import chat
# import PromptTemplate
from langchain.prompts import PromptTemplate

REPHRASE_TEMPLATE = PromptTemplate.from_template(
"""
Task: Given a multi-turn conversation and a follow-up user question, rewrite the follow-up as a clear, detailed, and standalone question suitable for retrieving relevant documents from a vector database.

- Use the context from the full conversation to preserve intent and necessary background.
- The rewritten question should not reference the conversation explicitly (e.g., avoid “as mentioned before”).
- Ensure the standalone question includes all important entities, topics, and context implied in the follow-up.
- Favor clarity and completeness over brevity.

Input:

Chat History:
{chat_history}

Follow-Up Question:
{input}

Rewritten Standalone Question:
"""
)

response = chat(
    model="qwen3",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": REPHRASE_TEMPLATE.format(
            chat_history="No chat history available.",
            input="What are the features of Open OnDemand?"
        )},
    ],
    think=False
)

print("Rewritten question:", response['message']['content'])

print("Retrieving documents...")
docs = retriever.invoke(
    response['message']['content'],
    search_type="similarity",
)

for doc in docs:
    print(f"Document source: {doc.metadata['source']}, tags: {doc.metadata['tags']}")
# Out:
# Rewritten question: What are the key features and functionalities of the Open OnDemand platform?
# Retrieving documents...
# Document source: https://rc.virginia.edu/userinfo/hpc/login/, tags: ['website', 'blog-post', 'userinfo', 'hpc', 'login', 'openondemand', 'rivanna', 'ssh', 'supercomputer']
# Document source: https://rc.virginia.edu/userinfo/hpc/ood/desktop/, tags: ['website', 'blog-post', 'HPC', 'software', 'lang']
# Document source: https://rc.virginia.edu/userinfo/hpc/ood/, tags: ['website', 'blog-post', 'userinfo', 'allocations', 'gpu', 'hpc', 'ood', 'parallel-computing', 'queues', 'rivanna']
